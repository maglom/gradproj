# %%
from datetime import datetime
import matplotlib.pyplot as plt
import meteostat as ms

# Set time period
start = datetime(2000, 4, 1)
end = datetime(2000, 9, 30)

bordeaux = ms.Point(44.837788, -0.579180)

# Get daily data for 2018
data = ms.Monthly(bordeaux, start, end)
data = data.fetch()

data

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()


df = data.iloc[:,:4]

df
# Out:
#             tavg  tmin  tmax   prcp
# time
# 2000-04-01  12.1   8.4  16.8  154.0
# 2000-05-01  17.2  12.6  22.5   99.0
# 2000-06-01  19.8  14.8  25.1   55.0
# 2000-07-01  20.0  15.2  25.2   59.0
# 2000-08-01  21.8  16.3  28.5   26.0
# 2000-09-01  18.9  13.9  25.0   43.0

# %%
df = df.stack().reset_index()
df
# Out:
#    level_0  level_1                    0
# 0     time        0  2000-04-01 00:00:00
# 1     time        1  2000-04-01 00:00:00
# 2     time        2  2000-04-01 00:00:00
# 3     time        3  2000-04-01 00:00:00
# 4     time        4  2000-05-01 00:00:00
# ..     ...      ...                  ...
# 67       0       19                 26.0
# 68       0       20                 18.9
# 69       0       21                 13.9
# 70       0       22                 25.0
# 71       0       23                 43.0
#
# [72 rows x 3 columns]

# %%
df = df.T

# %%
df
# Out:
#                           0                    1                    2   \
# time     2000-04-01 00:00:00  2000-04-01 00:00:00  2000-04-01 00:00:00
# level_1                 tavg                 tmin                 tmax
# 0                       12.1                  8.4                 16.8
#
#                           3                    4                    5   \
# time     2000-04-01 00:00:00  2000-05-01 00:00:00  2000-05-01 00:00:00
# level_1                 prcp                 tavg                 tmin
# 0                      154.0                 17.2                 12.6
#
#                           6                    7                    8   \
# time     2000-05-01 00:00:00  2000-05-01 00:00:00  2000-06-01 00:00:00
# level_1                 tmax                 prcp                 tavg
# 0                       22.5                 99.0                 19.8
#
#                           9   ...                   14                   15  \
# time     2000-06-01 00:00:00  ...  2000-07-01 00:00:00  2000-07-01 00:00:00
# level_1                 tmin  ...                 tmax                 prcp
# 0                       14.8  ...                 25.2                 59.0
#
#                           16                   17                   18  \
# time     2000-08-01 00:00:00  2000-08-01 00:00:00  2000-08-01 00:00:00
# level_1                 tavg                 tmin                 tmax
# 0                       21.8                 16.3                 28.5
#
#                           19                   20                   21  \
# time     2000-08-01 00:00:00  2000-09-01 00:00:00  2000-09-01 00:00:00
# level_1                 prcp                 tavg                 tmin
# 0                       26.0                 18.9                 13.9
#
#                           22                   23
# time     2000-09-01 00:00:00  2000-09-01 00:00:00
# level_1                 tmax                 prcp
# 0                       25.0                 43.0
#
# [3 rows x 24 columns]
