# %%
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# Set time period
start = datetime(2000, 1, 1)
end = datetime(2000, 12, 31)

bordeaux = Point(44.837788, -0.579180)

# Get daily data for 2018
data = Daily(bordeaux, start, end)
data = data.fetch()

data

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()


df = data.iloc[:,:4]

df
# Out:
#             tavg  tmin  tmax  prcp
# time
# 2000-01-01   9.6   8.9  11.8   1.4
# 2000-01-02   8.9   7.0  10.6   0.2
# 2000-01-03   6.2   1.8  12.7   0.4
# 2000-01-04   7.2   1.9  11.2   0.0
# 2000-01-05   9.6   5.6  13.6   0.2
# ...          ...   ...   ...   ...
# 2000-12-27   8.9   7.1  12.3   8.6
# 2000-12-28   4.5   1.0   6.3   7.4
# 2000-12-29   5.5   1.6   8.8  16.6
# 2000-12-30   3.9   2.7   5.8   2.4
# 2000-12-31   2.2  -2.2   7.5   0.4
#
# [366 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 366 entries, 2000-01-01 to 2000-12-31
# Freq: D
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tavg    366 non-null    float64
#  1   tmin    366 non-null    float64
#  2   tmax    366 non-null    float64
#  3   prcp    366 non-null    float64
# dtypes: float64(4)
# memory usage: 14.3 KB

# %%
df.describe()
# Out:
#              tavg        tmin        tmax        prcp
# count  366.000000  366.000000  366.000000  366.000000
# mean    14.003279    9.917486   18.886066    3.302186
# std      5.792011    5.365993    6.889762    6.581464
# min     -1.500000   -4.900000   -0.600000    0.000000
# 25%      9.725000    6.425000   13.300000    0.000000
# 50%     13.300000   10.150000   18.400000    0.200000
# 75%     18.300000   14.275000   24.200000    3.000000
# max     27.200000   21.100000   35.500000   52.400000
